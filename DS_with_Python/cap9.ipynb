# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
data = np.random.rand(10)
print(data)

plt.plot(data)
# Out:
# [5.49630336e-01 7.32637327e-01 7.73569511e-01 7.97795939e-01
#  5.18318778e-01 3.57581722e-01 6.26318538e-01 8.32153404e-01
#  6.55087507e-01 1.85974044e-04]

# %%
imagem = plt.figure()
ax1 = imagem.add_subplot(2,2,1)
ax2 = imagem.add_subplot(2,2,2)
ax3 = imagem.add_subplot(2,2,3)

# %%
#exemplo de subplot

imagem = plt.figure()
ax1 = imagem.add_subplot(2,2,1)
plt.plot(np.random.randn(10).cumsum(), 'k-')
ax2 = imagem.add_subplot(2,2,2)
plt.plot(np.random.random(10).cumsum())
ax3 = imagem.add_subplot(2,2,3)
plt.plot(np.random.randn(10), 'k--')

# %%
imagem = plt.figure()
ax1 = imagem.add_subplot(2,2,1)
plt.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
ax2 = imagem.add_subplot(2,2,2)
plt.hist(np.random.randn(50), bins=30, color='red')
ax3 = imagem.add_subplot(2,2,3)
plt.plot(np.random.randn(10), 'k--')

# %%
plt.plot(np.random.randn(15),'ko--' )

# %%
exem = np.random.randn(20).cumsum()

plt.plot(exem,'k--', label='default' )
plt.plot(exem, 'k-', drawstyle='steps-post', label='steps-post')

# %%
import pandas as pd
new_way = pd.Series(np.arange(30).cumsum() + 3 * np.random.randn(30))
new_way.tail()
new_way.plot()

# %%
new_way2 = pd.DataFrame(np.random.randn(10,4), 
    columns=['Aa', 'Bb', 'Cc', 'Dd'],
    index = np.arange(0,100,10) )

new_way2.cumsum().plot()

# %%
imagem = plt.figure()
ax1 = imagem.add_subplot(2,2,1)
new_way2['Aa'].plot.bar()
ax2 = imagem.add_subplot(2,2,2)
new_way2['Bb'].cumsum().plot.bar()
ax3 = imagem.add_subplot(2,2,3)
new_way2['Cc'].cumsum().plot.bar()
ax4 = imagem.add_subplot(2,2,4)
new_way2['Dd'].cumsum().plot.bar()

# %%
new_way2.cumsum().plot.bar()
new_way2.cumsum().plot.barh(stacked = True)

# %%
new_data = np.random.rand(15,4)
new_data = pd.DataFrame(new_data , columns= ['Ab', 'Bc', 'Cd', 'De']).cumsum()
new_data.head()
new_data.plot.barh(stacked = True)

# %%
# como deixar de 0 a 1 (porcentagem)
new_data.div(new_data.sum(1), axis=0).plot.bar()

# %%
 # autenticando api
 from kaggle.api.kaggle_api_extended import KaggleApi
 api = KaggleApi()
 api.authenticate()

# %%
## extraindo os dados
import pandas as pd
import seaborn as sns
from zipfile import ZipFile

# baixando pelo api
api.dataset_download_files('ranjeetjain3/seaborn-tips-dataset')
api.dataset_download_files('jannadimakrem/wid-tn-macrodata')

#  extraindo dados do arquivo zip

zf = ZipFile('/home/slraul/traning_projects/DS_with_Python/seaborn-tips-dataset.zip', 'r')
zf.extractall('/home/slraul/traning_projects/DS_with_Python')
zf.close()

zf2 = ZipFile('/home/slraul/traning_projects/DS_with_Python/wid-tn-macrodata.zip', 'r')
zf2.extractall('/home/slraul/traning_projects/DS_with_Python')
zf2.close()

tips = pd.read_csv('tips.csv', sep = ',')
MacroData = pd.read_csv('WID_TN_MacroData.csv', sep = ',')
MacroData.head()
# Out:
#   country  year    perc  \
# 0      TN  2017  p0p100
# 1      TN  2016  p0p100
# 2      TN  2015  p0p100
# 3      TN  2014  p0p100
# 4      TN  2013  p0p100
#
#    Consumption of fixed capital of national economy | individuals | Average | Adults | constant 2015 local currency  \
# 0                                        1821.619385
# 1                                        1820.860229
# 2                                        1818.875732
# 3                                        1818.851807
# 4                                        1816.740356
#
#    Consumption of fixed capital of national economy | individuals | Average | All Ages | constant 2015 local currency  \
# 0                                        1258.012451
# 1                                        1256.009888
# 2                                        1254.485229
# 3                                        1252.262939
# 4                                        1248.416016
#
# ...

# %%
# vizualizando tips

sns.barplot(y='time', x='total_bill', data=tips)

# %%
sns.barplot(y='sex', x='total_bill', data=tips)

# %%
sns.barplot(x='smoker', y='total_bill', data=tips)

# %%
tips.total_bill.plot.hist()

# %%
tips.total_bill.plot.density()

# %%
import seaborn as sns 
rnorme = pd.Series(np.random.normal(0,1,size = 200))
sns.distplot(rnorme)
# Out:
# /home/slraul/.local/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# visao de reg
sns.regplot(x= 'total_bill',y= 'tip',data=tips)

# %%
# cruzando todas as variáveis
sns.pairplot(tips, diag_kind='kde')

# %%
sns.factorplot(x= 'day', y= 'tip',hue='time' ,col = 'smoker', kind='bar' ,data= tips)
# Out:
# /home/slraul/.local/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x= 'day', y= 'tip',row='time' ,col = 'smoker', kind='bar' ,data= tips)
# Out:
# /home/slraul/.local/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x= 'day', y= 'tip', kind='box' ,data= tips)
# Out:
# /home/slraul/.local/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
